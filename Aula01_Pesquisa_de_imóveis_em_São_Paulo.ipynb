# %% [markdown]
# # [Alura] Imersão Dados
#
# # Aula 01 - Primeiro colab com Python e Pandas
# ## Pesquisa de imóveis em São Paulo

# %% [markdown]
# ## Importando base de dados
#
# A base de dados contém informações anonimizadas sobre preços de imóveis de São Paulo - SP.

# %%
import pandas as pd

url_dados = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"

dados = pd.read_csv(url_dados)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %% [markdown]
# ## Primeiras visualizações e informações básicas sobre os dados

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados.sample(10)
# Out:
#                                  Rua                Bairro     Cidade  \
# 4506      Rua Ministro Sinésio Rocha      Jardim Vera Cruz  São Paulo
# 5187  Rua Coronel Irlandino Sandoval     Jardim Paulistano  São Paulo
# 948   Rua Comissário Gastão Moutinho               Morumbi  São Paulo
# 8461                             NaN       Chácara Inglesa  São Paulo
# 7675               Rua Laplace, 962               Brooklin  São Paulo
# 8582                             NaN        Vila Congonhas  São Paulo
# 4465                             NaN              Vila Ida  São Paulo
# 2187          Avenida Tomás de Sousa     Jardim Monte Azul  São Paulo
# 7941            Rua Sibipiruna, 466   Parque dos Príncipes  São Paulo
# 2456                       Rua Paris                Sumaré  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# 4506       150        4          3      2  R$ 1.300.000
# 5187       390        4          4      5  R$ 5.050.000
# 948       1000        4          6      6  R$ 5.500.000
# 8461        80        2          2      1    R$ 640.000
# 7675       639        5          4      4  R$ 2.800.000
# 8582       125        3          2      2    R$ 763.200
# 4465       527        8          8      8  R$ 2.850.000
# 2187       325        4          5      7  R$ 1.000.000
# 7941       725        3          3      6  R$ 5.000.000
# 2456       150        3          3      2  R$ 1.200.000

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados['Bairro'][6522]
# Out:
# 'Vila Paulo Silas'

# %% [markdown]
# O valor (preço) dos imóveis está com o tipo *object*, que não aceita cálculos matemáticos.

# %% [markdown]
# ## Médias de metragem

# %%
media = dados.Metragem.mean() 
print( "Média da metragem de todos os imóveis = " + str(media))
# Out:
# Média da metragem de todos os imóveis = 442.30065947242207

# %%
bairro_consulta = "Aclimação"

filtro_imoveis_consulta = dados["Bairro"] == bairro_consulta
qnt_imoveis_consulta = sum(filtro_imoveis_consulta)

print("Há " + str(qnt_imoveis_consulta) + " imóveis no bairro " + bairro_consulta)
# Out:
# Há 88 imóveis no bairro Aclimação

# %%
imoveis_consulta = dados[filtro_imoveis_consulta]
imoveis_consulta
# Out:
#                                              Rua     Bairro     Cidade  \
# 269                              Rua Ximbó, 410   Aclimação  São Paulo
# 670                          Rua Alabastro, 151   Aclimação  São Paulo
# 1265                           Rua Carlos Chagas  Aclimação  São Paulo
# 1287                        Rua Doutor João Maia  Aclimação  São Paulo
# 1347                        Rua Doutor João Maia  Aclimação  São Paulo
# ...                                          ...        ...        ...
# 9260  Rua Doutor Rafael Caramuru Lanzelloti, 77   Aclimação  São Paulo
# 9366                                Rua Baturité  Aclimação  São Paulo
# 9418                           Rua André Gouveia  Aclimação  São Paulo
# 9539                                    Rua Rubi  Aclimação  São Paulo
# 9776                       Rua Oscar Guanabarino  Aclimação  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 269        140        4          3      4
# 670        129        3          2      3
# 1265       280        3          2      2
# 1287       380        3          5      2
# 1347       385        3          5      2
# ...        ...      ...        ...    ...
# 9260       120        3          2      1
# 9366       156        3          4      1
# 9418       199        3          4      3
# 9539      1500        4          2      6
# 9776       300        3          3      3
#
#                                      Valor
# 269                             R$ 800.000
# 670                             R$ 960.000
# 1265                          R$ 2.200.000
# 1287                          R$ 2.660.000
# 1347                          R$ 2.660.000
# ...                                    ...
# 9260                            R$ 900.001
# 9366                            R$ 800.000
# 9418                          R$ 1.930.000
# 9539                          R$ 5.000.000
# 9776  R$ 7.000\n                      /Mês
#
# [88 rows x 8 columns]

# %%
media_consulta = imoveis_consulta.Metragem.mean() 
print( "Média da metragem dos imóveis do bairro " + bairro_consulta + " = " + str(media_consulta))
# Out:
# Média da metragem dos imóveis do bairro Aclimação = 253.0568181818182

# %% [markdown]
# ## Análise por bairro

# %%
qnt_imoveis_bairro = dados["Bairro"].value_counts()
qnt_imoveis_bairro
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %% [markdown]
# 10 Bairros com mais imóveis disponíveis

# %%
qnt_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# # Desafios

# %% [markdown]
# ##1. Realizar a média da metragem para cada um dos bairros

# %%
grupo_bairros = dados.groupby('Bairro')
grupo_bairros.groups
# Out:
# {'Aclimação': [269, 670, 1265, 1287, 1347, 1663, 1763, 2044, 2141, 2369, 2438, 2734, 2764, 2800, 2818, 2855, 3017, 3045, 3433, 3612, 3737, 3748, 3758, 3759, 3818, 3895, 3920, 4024, 4028, 4032, 4083, 4084, 4125, 4131, 4164, 4177, 4181, 4188, 4192, 4224, 4254, 4264, 4312, 4348, 4375, 4415, 4467, 4474, 4490, 4515, 4523, 4527, 4571, 4617, 4860, 4890, 4940, 4971, 4993, 5266, 5344, 5452, 5504, 5574, 5635, 5698, 5777, 5936, 6033, 6201, 6277, 6293, 6468, 6528, 6722, 6809, 6834, 7153, 7454, 7563, 8293, 9067, 9140, 9260, 9366, 9418, 9539, 9776], 'Alto da Boa Vista': [65, 143, 339, 3426, 4123, 5310, 6234, 8145], 'Alto da Lapa': [61, 86, 91, 158, 169, 236, 252, 321, 425, 440, 446, 459, 477, 500, 502, 917, 1225, 1588, 1795, 1838, 1932, 2028, 2068, 2127, 2167, 2171, 2233, 2705, 2840, 2949, 2982, 3129, 3359, 3602, 3641, 3684, 3864, 4203, 4499, 4551, 4630, 4689, 4915, 4934, 4963, 4986, 5263, 5268, 5365, 5392, 5488, 5558, 5786, 5867, 5945, 5992, 6027, 6168, 6300, 6334, 6391, 6516, 6604, 6693, 6716, 6743, 6803, 7121, 7152, 7259, 7546, 7776, 7860, 8241, 8688, 8750, 8958, 9103, 9217, 9321, 9328, 9380, 9442, 9509, 9802, 9834], 'Alto da Mooca': [2324, 2435, 2451, 2494, 5218, 5541, 5676, 6019, 6084, 6191, 6712, 6895, 7496, 7547, 7686, 8229, 8243, 8396, 9265, 9332], 'Alto de Pinheiros': [83, 84, 137, 214, 226, 227, 232, 253, 319, 376, 399,
 2685, 2723, 2753, 2849, 3023, 4119, 4143, 4760, 4881, 5248, 5731, 6149, 6159, 6229, 6271, 6365, 6484, 6501, 6672, 6683, 6914, 6928, 6972, 7188, 7485, 7675, 8347, 8383, 9243, 9370, 9502, 9518, 9644, 9709, 9745], 'Brooklin Novo': [860, 890, 1602, 1672, 1705, 5534, 5669, 6184, 9756, 9846], 'Brooklin Paulista': [50, 104, ...

# %%
media_metragem_por_bairro = pd.DataFrame(grupo_bairros['Metragem'].mean()).rename(columns = {'Metragem':'Média da Metragem'})
media_metragem_por_bairro.sort_values(by = 'Média da Metragem', inplace = True, ascending = False)
media_metragem_por_bairro
# Out:
#                                     Média da Metragem
# Bairro
# Sítio Represa                            37000.000000
# Vila Castelo                              2850.000000
# Jardim Guedala                            2486.640199
# Jardim das Camélias                       1700.000000
# Chácara Flora                             1260.727273
# ...                                               ...
# Cidade Antônio Estevão de Carvalho          57.500000
# Jardim Nova Germania                        57.000000
# Jardim Benfica                              48.000000
# Vila Leonor                                 46.000000
# Vila Guaca                                  10.000000
#
# [701 rows x 1 columns]

# %%
media_metragem_por_bairro.head(10).plot.bar()

# %% [markdown]
# A base de dados contém, dentre os imóveis para venda e aluguél, sítios e chácaras, que podem ser analisados separadamente.

# %% [markdown]
# ## 2. Duas formas de selecionar os dados por bairro

# %% [markdown]
# 1. Máscara pelo nome do bairro: gera uma series booleana que pode ser usada sobre os dados.

# %%
bairro_consulta = "Aclimação"

filtro_imoveis_consulta = dados["Bairro"] == bairro_consulta
dados[filtro_imoveis_consulta]
# Out:
#                                              Rua     Bairro     Cidade  \
# 269                              Rua Ximbó, 410   Aclimação  São Paulo
# 670                          Rua Alabastro, 151   Aclimação  São Paulo
# 1265                           Rua Carlos Chagas  Aclimação  São Paulo
# 1287                        Rua Doutor João Maia  Aclimação  São Paulo
# 1347                        Rua Doutor João Maia  Aclimação  São Paulo
# ...                                          ...        ...        ...
# 9260  Rua Doutor Rafael Caramuru Lanzelloti, 77   Aclimação  São Paulo
# 9366                                Rua Baturité  Aclimação  São Paulo
# 9418                           Rua André Gouveia  Aclimação  São Paulo
# 9539                                    Rua Rubi  Aclimação  São Paulo
# 9776                       Rua Oscar Guanabarino  Aclimação  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 269        140        4          3      4
# 670        129        3          2      3
# 1265       280        3          2      2
# 1287       380        3          5      2
# 1347       385        3          5      2
# ...        ...      ...        ...    ...
# 9260       120        3          2      1
# 9366       156        3          4      1
# 9418       199        3          4      3
# 9539      1500        4          2      6
# 9776       300        3          3      3
#
#                                      Valor
# 269                             R$ 800.000
# 670                             R$ 960.000
# 1265                          R$ 2.200.000
# 1287                          R$ 2.660.000
# 1347                          R$ 2.660.000
# ...                                    ...
# 9260                            R$ 900.001
# 9366                            R$ 800.000
# 9418                          R$ 1.930.000
# 9539                          R$ 5.000.000
# 9776  R$ 7.000\n                      /Mês
#
# [88 rows x 8 columns]

# %% [markdown]
# 2. Agrupamento por bairros: gera um DataFrameGroup que agrupa valores iguais e facilita cálculos e buscas sem precisar de for.

# %%
grupo_bairros = dados.groupby('Bairro')
type(grupo_bairros)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
#
São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 269        140        4          3      4
# 670        129        3          2      3
# 1265       280        3          2      2
# 1287       380        3          5      2
# 1347       385        3          5      2
# ...        ...      ...        ...    ...
# 9260       120        3          2      1
# 9366       156        3          4      1
# 9418       199        3          4      3
# 9539      1500        4          2      6
# 9776       300        3          3      3
#
#                                      Valor
# 269                             R$ 800.000
# 670                             R$ 960.000
# 1265                          R$ 2.200.000
# 1287                          R$ 2.660.000
# 1347                          R$ 2.660.000
# ...                                    ...
# 9260                            R$ 900.001
# 9366                            R$ 800.000
# 9418                          R$ 1.930.000
# 9539                          R$ 5.000.000
# 9776  R$ 7.000\n                      /Mês
#
# [88 rows x 8 columns]

# %% [markdown]
# 3. Filtragem por conjunto

# %%
consultas = ["Vila Mariana", "Aclimação"]
dados[dados.Bairro.isin(consultas)]
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 269                Rua Ximbó, 410      Aclimação  São Paulo       140
# ...                            ...           ...        ...       ...
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9776         Rua Oscar Guanabarino     Aclimação  São Paulo       300
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas                                 Valor
# 100         3          3      1                          R$ 1.350.000
# 120         3          5      2                          R$ 2.450.000
# 155         3          4      2                          R$ 1.490.000
# 160         4          5      3                          R$ 2.200.000
# 269         4          3      4                            R$ 800.000
# ...       ...        ...    ...                                   ...
# 9701        3          2      4                          R$ 1.650.000
# 9737        3          2      4                          R$ 1.650.000
# 9776        3          3      3  R$ 7.000\n                      /Mês
# 9807        3          1      6                          R$ 1.500.000
# 9852        3          3      4                          R$ 1.600.000
#
# [272 rows x 8 columns]

# %% [markdown]
# ## 3. Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, assim como tentar colocar alguma conclusão.

# %%
media_quartos_por_bairro = pd.DataFrame(grupo_bairros['Quartos'].mean()).rename(columns = {'Quartos':'Média de Quartos'})
media_quartos_por_bairro.sort_values(by = 'Média de Quartos', inplace = True, ascending = False)

media_quartos_por_bairro.head(5).plot.area()
media_metragem_por_bairro.head(5).plot.area()

# %% [markdown]
# Os bairros com imóveis com maiores médias de metragem não estão dentre os bairros com maiores médias de quartos por imóvel.

# %% [markdown]
# A falta de informação sobre o tipo de imóvel e a classificação aluguel ou venda distorce muito os possíveis resultados que podemos chegar. Por exemplo:
#   - Há imóveis com metragem muito acima da média (como o Sítio Represa) e com poucos quartos. A informação não apenas abrange o imóvel, mas também o lote completo do sítio. Este tipo de dado atrapalharia uma análise de metragem por quantidade de cômodos, por exemplo.
#   - Há imóveis que estão para locação cujo valor é muito mais baixo do que o valor de venda. Essa diferença distorceria muito métricas relacionadas aos preços.
#
# As diferenciações entre alugel e venda podem ser extraídas com um tratamento sobre a coluna "Valor", o tipo de lote pode ser extraído do nome do bairro.

# %% [markdown]
# ## 4. Pegar outras estatísticas dos dados (como média, mediana, mim, max)

# %% [markdown]
# ### Média

# %%
media_metragem_por_bairro = pd.DataFrame(grupo_bairros['Metragem'].mean()).rename(columns = {'Metragem':'Média da Metragem'})

media_metragem_por_bairro.head(10).plot.bar()
media_metragem_por_bairro
# Out:
#                    Média da Metragem
# Bairro
# Aclimação                 253.056818
# Alto da Boa Vista         418.875000
# Alto da Lapa              294.337209
# Alto da Mooca             270.050000
# Alto de Pinheiros         433.444988
# ...                              ...
# Vila Água Funda           152.200000
# Água Branca               191.000000
# Água Fria                 165.416667
# Água Funda                139.000000
# Água Rasa                 340.250000
#
# [701 rows x 1 columns]

# %% [markdown]
# ### Mediana

# %%
mediana_quartos_por_bairro = pd.DataFrame(grupo_bairros['Quartos'].median()).rename(columns = {'Quartos':'Mediana da Quantidade de Quartos'})

mediana_quartos_por_bairro.head(10).plot.bar()
mediana_quartos_por_bairro
# Out:
#                    Mediana da Quantidade de Quartos
# Bairro
# Aclimação                                       3.0
# Alto da Boa Vista                               4.0
# Alto da Lapa                                    3.0
# Alto da Mooca                                   3.0
# Alto de Pinheiros                               4.0
# ...                                             ...
# Vila Água Funda                                 2.0
# Água Branca                                     3.0
# Água Fria                                       3.0
# Água Funda                                      3.0
# Água Rasa                                       3.0
#
# [701 rows x 1 columns]

# %% [markdown]
# ### Mínimo (menor metragem por bairro)

# %%
min_metragem_por_bairro = pd.DataFrame(grupo_bairros['Metragem'].min()).rename(columns = {'Metragem':'Menor Metragem'})

min_metragem_por_bairro.head(10).plot.bar()
min_metragem_por_bairro
# Out:
#                    Menor Metragem
# Bairro
# Aclimação                     104
# Alto da Boa Vista             315
# Alto da Lapa                   46
# Alto da Mooca                  84
# Alto de Pinheiros             100
# ...                           ...
# Vila Água Funda                90
# Água Branca                    91
# Água Fria                      60
# Água Funda                    125
# Água Rasa                      86
#
# [701 rows x 1 columns]

# %% [markdown]
# ### Máximo (maior metragem por bairro)

# %%
max_metragem_por_bairro = pd.DataFrame(grupo_bairros['Metragem'].max()).rename(columns = {'Metragem':'Maior Metragem'})

max_metragem_por_bairro.head(10).plot.bar()
max_metragem_por_bairro
# Out:
#                    Maior Metragem
# Bairro
# Aclimação                    1500
# Alto da Boa Vista             595
# Alto da Lapa                 1133
# Alto da Mooca                 805
# Alto de Pinheiros            1530
# ...                           ...
# Vila Água Funda               200
# Água Branca                   400
# Água Fria                     314
# Água Funda                    153
# Água Rasa                     805
#
# [701 rows x 1 columns]

# %% [markdown]
# ## 5. Descobrir quais são os bairros que não tem nome de rua

# %%
ruas_nan = dados['Rua'].isnull()

# %%
bairros_sem_rua = dados['Bairro'][ruas_nan].drop_duplicates()
pd.DataFrame(bairros_sem_rua).rename(columns = {'Bairro':'Bairro sem rua'})
# Out:
#                         Bairro sem rua
# 3                       Jardim Morumbi
# 11                    Jardim Luzitânia
# 31                      Parque da Lapa
# 56    Chácara Santo Antônio (Zona Sul)
# 57                      Jardim Guedala
# ...                                ...
# 9672               Jardim Vila Formosa
# 9774                            Cupecê
# 9780                  Jardim Itacolomi
# 9816                         Água Rasa
# 9917              Parque Alves de Lima
#
# [394 rows x 1 columns]
